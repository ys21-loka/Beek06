# %%
import pandas as pd
import numpy as np

dataset = pd.read_excel('./sum_all_data.xlsx', header=0)


import matplotlib.pyplot as plt
import seaborn as sns

cols_a = ['SO', 'H', 'W', 'gao', 'Hand']
cols_b = ['f_ev', 'b_ev', 'F_SPIN', 'B_SPIN', 'OBP', 'SLG', 'Hand']

sns.relplot(x='Height', y='FIP', height=2.5, hue="Hand", data=dataset)
plt.show()

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

cols = ['FIP', 'Height']
dataset = dataset.dropna()

cm = np.corrcoef(dataset[cols].values.T)
print(cm)
# Out:
# [[ 1.         -0.17331171]
#  [-0.17331171  1.        ]]

# %%
sns.boxplot(x="Hand", y="FIP", data=dataset)

# %%
import seaborn as sns
sns.distplot(dataset["Height"], kde=False, rug=True)

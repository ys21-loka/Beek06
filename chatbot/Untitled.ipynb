# %%
import requests
import urllib
from bs4 import BeautifulSoup
import json
from gtts import gTTS
import IPython.display as ipd
from IPython.core.display import HTML
from flask import Flask

# %%
def getWeather(city) :    
    url = "https://search.naver.com/search.naver?query="
    url = url + urllib.parse.quote_plus(city + "날씨")
    print(url)
    bs = BeautifulSoup(urllib.request.urlopen(url).read(), "html.parser")
    temp = bs.select('span.todaytemp')    
    desc = bs.select('p.cast_txt')    
    return  {"temp":temp[0].text, "desc":desc[0].text}

# %%
def getwcl(server, name):
    url = "https://www.warcraftlogs.com/character/kr/"
    url = url + urllib.parse.quote_plus(server) + "/" + urllib.parse.quote_plus(name)
    bs = BeautifulSoup(urllib.request.urlopen(url).read(), "html.parser")
    print(bs)
    temp = bs.select('character-basics')
    desc = bs.select('top-box > div.stats > div.best-perf-avg > b')

# %%
getwcl('세나리우스', '신사동자')
# Out:
# <!DOCTYPE doctype html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <meta content="World of Warcraft, WoW, MMO, MMORPG, Games, Raid, Combatlog, DPS, Blizzard, Final Fantasy, WildStar, Elder Scrolls, Video Games, Multiplayer, Online Games, Mods, Trion, Rift" name="keywords"/>
# <title>
# 신사동자 - 세나리우스 - Warcraft Logs
# </title>
# <title>Warcraft Logs - Combat Analysis for Warcraft</title>
# <link href="https://dmszsuqyoe6y6.cloudfront.net/css/global.min.css?v=17" rel="stylesheet" type="text/css"/>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/material-design-iconic-font/2.2.0/css/material-design-iconic-font.min.css" rel="stylesheet" type="text/css"/>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/malihu-custom-scrollbar-plugin/3.1.5/jquery.mCustomScrollbar.min.css" rel="stylesheet" type="text/css"/>
# ...

# %%
def gettier(name) :    
    url = "https://www.op.gg/summoner/userName="
    url = url + urllib.parse.quote_plus(name) 
    bs = BeautifulSoup(urllib.request.urlopen(url).read(), "html.parser")
    tier = bs.select('div.TierRank')    
    return {"tier":tier[0].text}

# %%
gettier("연애왕모솔")
# Out:
# {'tier': 'Silver 3'}

# %%
sessid = 'park'
datas = {}
datas[sessid] = [0,0,0]
print(datas[sessid]) #지칭 대상 불명확 -> 리스트 대신 딕셔너리를 사용할까?
# Out:
# [0, 0, 0]

# %%
class User:
    def __init__(self):
        self.win = 0
        self.lose = 0
        self.draw = 0
        
p1 = User()
p2 = User()

p1.win = 3
p1.lose = 5

p2.win = 7
p2.lose = 10

datas[sessid] = p1

print(datas[sessid].win)
# Out:
# 3
